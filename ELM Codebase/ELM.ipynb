# %%
import sys
if "./" not in sys.path:
    sys.path.append("./") 

import ELM
elm = ELM.ELM({"split": 0.8, "lag": 3, "step_forward": 0, "Hidden Neurons": 3, "Random State": 212, "Train Range": [1000, 10000]})

# %%
elm.load_data()

# %%
elm.plot_input_data({"xlabel": "Samples", "ylabel": "Signal Value", "grid": True})

# %%
_ = elm.train_and_predict()

# %%
ELM.testELM()
# Out:
# Timestep:  0  -> MAE: 0.0063, RMSE: 0.0203, R2: 78.0397
# Timestep:  1  -> MAE: 0.0088, RMSE: 0.0284, R2: 57.2428
# Timestep:  3  -> MAE: 0.0157, RMSE: 0.0427, R2: 3.8489
# Timestep:  6  -> MAE: 0.0162, RMSE: 0.0441, R2: -2.4288
# Timestep:  18  -> MAE: 0.0137, RMSE: 0.0411, R2: 11.7849
